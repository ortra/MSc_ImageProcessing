# %% [markdown]
# Student IDs: 301613501, 208560086

# %% [markdown]
# **Mount to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# **Change working directory to lab folder**

# %%
# %cd '/content/drive/My Drive/IP Labs/1/'
import os
path = os.getcwd() 
print('path: ' + path)
# Out:
# /content/drive/My Drive/IP Labs/1
# path: /content/drive/My Drive/IP Labs/1

# %% [markdown]
# **Imports**

# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pylab as plt
from skimage import color, img_as_ubyte

# %% [markdown]
# **Load image and convert to grayscale**
# *   Load your image and convert it to grayscale.

# %%
# load original
my_img = plt.imread('Lab1_Image.bmp')

# conversion to uint8 grayscale
im_gray = color.rgb2gray(my_img)
im_gray = img_as_ubyte(im_gray)

# %% [markdown]
# *   Display your original and grayscale images. Add titles to your images.

# %%
# create figure
fig = plt.figure()

# setting values to rows and column variables
rows = 1
columns = 2
 
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(my_img)
plt.axis('off')
plt.title("Original")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(im_gray,cmap = 'gray')
plt.axis('off')
plt.title("Gray")

plt.show()

# %% [markdown]
# **Apply thresholding on your grayscale image**
#
# *   Write a new function named *img_thresholding(img, T)*.
# *   Your function should generate a binary image *bin_img* through  thresholding the grayscale image *img*:
# >> *bin_img* is white where *img > T*, *bin_img* is black elsewhere.
# *   The function returns *bin_img*.
# *   **Use no loops!**

# %%
### This function gets image and 256Bits tresholds ### 
### and returns black and white image              ###

def img_thresholding(img, T):
  
  bin_img = (img > T)
  return bin_img

# %% [markdown]
# *   Call your function setting *T = 0.25 x M, 0.5 x M, 0.75 x M* where *M* is the maximum pixel intensity of your grayscale image.
#
# *   Display your generated images. Don't forget to add titles!

# %%
# Find maximum pixel intensity
M = np.max(im_gray)
print('The pixle intensity threshold is: ' ,M , '\n')

# define a T vector
T = ( 0.25 * M, 0.5 * M, 0.75 * M )

# create figure
fig_new = plt.figure(figsize=(20,7))

# setting values to rows and column variables
rows = 1
columns = 3

for i,t in enumerate (T):
  fig_new.add_subplot(rows, columns, i+1)
  plt.imshow(img_thresholding(im_gray, t),cmap = 'gray')
  plt.axis('off')
  plt.title('Pixel Intensity TH - ' + str(t))
# Out:
# The pixle intensity threshold is:  226
