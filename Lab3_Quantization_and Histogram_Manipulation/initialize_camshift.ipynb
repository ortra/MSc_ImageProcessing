# %% [markdown]
# <a href="https://colab.research.google.com/github/naorJR/IP-Labs/blob/ortra/Lab%203/initialize_camshift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd '/content/drive/My Drive/IP Labs/3'
# %ls -l
# Out:
# /content/drive/My Drive/IP Labs/3
# total 2695
# -rw------- 1 root root     180 Nov 26 16:58 ex3_pre_301613501_208560086.gdoc
# -rw------- 1 root root  278540 Nov 26 14:46 ex3_pre_code.ipynb
# -rw------- 1 root root    1123 Nov 26 18:19 initialize_camshift.ipynb
# -rw------- 1 root root   14718 Nov 26 14:05 Lab3.ipynb
# -rw------- 1 root root   55609 Nov 26 10:21 LowContrast.jpeg
# -rw------- 1 root root  106269 Nov 26 12:32 moo2.gif
# -rw------- 1 root root 2300671 Oct 13  2021 MOT16-04-trimmed.mp4

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture('MOT16-04-trimmed.mp4')

# take first frame of the video
ret,frame = cap.read()

# setup initial location of window
#### INSERT THE ROI VALUES HERE ###
x,y,h,w = 505, 62, 100, 50 
track_window = (x,y,w,h)

# Draw window on image
points = np.array([[x,y], [x+w, y], [x+w, y+h],  [x, y+h]])
img1 = cv2.polylines(frame,[points],True, 255,2)
cv2_imshow(img1)

cv2.destroyAllWindows()
cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=960x540 at 0x7F60B1788790>
